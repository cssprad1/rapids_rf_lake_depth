# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
import fiona

# %%
import os
try:
    import descartes
except ModuleNotFoundError:
    os.system('conda install -c conda-forge descartes')

# %%
#%matplotlib widget
# %matplotlib inline

# %%
TIF_PATH = '/att/nobackup/maronne/lake/forCaleb/'
object_shape = gpd.read_file(TIF_PATH+'awm_ak_maxwater_with_2001.shp')

# %%
object_shape.crs
# Out:
# <Projected CRS: PROJCS["Alaska_Albers_Equal_Area_Conic",GEOGCS["NA ...>
# Name: Alaska_Albers_Equal_Area_Conic
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
object_shape.plot()
# Out:
# <AxesSubplot:>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-df054c802cc0> in <module>
# ----> 1 band1 = object_shape.read(1)
#       2 band1
#
# ~/.conda/envs/rapids-0.16/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'read'
