# %%
import pandas as pd
import cudf
import numpy as np

# %%
lakes_df_depth = pd.read_csv('../data/LakeDepthPoints_July2017.csv')
lakes_df_data = pd.read_csv('../data/pts_merged_final.csv')
lakes_df_data.drop(['FID','Date'], axis = 1)
# Out:
#         Depth_m  b1_LC8_075  b2_LC8_075  b3_LC8_075  b4_LC8_075  b5_LC8_075  \
# 0      0.630000         164         271         199          42          27
# 1      0.672727         165         272         196          44          29
# 2      0.670588         154         260         193          40          32
# 3      0.822222         156         250         195          48          40
# 4      1.725000         117         164          78          38          23
# ...         ...         ...         ...         ...         ...         ...
# 23172  1.887000         103         284         242         731         494
# 23173  2.012610         155         360         323         950         607
# 23174  2.041730         199         427         447        1253         880
# 23175  1.986000         241         552         557        1776        1211
# 23176  1.766450         276         644         649        2459        1662
#
#        b6_LC8_075  b7_LC8_075  b8_LC8_075  b9_LC8_075  ...  b26_LC8_07  \
# 0              16         605         824        3905  ...        2625
# 1              16         607         842        3750  ...        2750
# 2              19         592         798        3850  ...        2105
# 3              26         624         800        3250  ...        1846
# 4              17         713        1500        3079  ...        2235
# ...           ...         ...         ...         ...  ...         ...
# 23172         397         363         426         141  ...        1841
# 23173         462         431         480         163  ...        2056
# 23174         575         466         445         159  ...        2179
# 23175         809         437         433         136  ...        2195
# 23176         921         429         425         112  ...        2670
#
#        b27_LC8_07  b28_LC8_07  b29_LC8_07  b30_LC8_07  b31_LC8_07  b32_LC8_07  \
# 0             165         100         136         643          98          59
# 1             176         107         148         659          97          59
# 2             208         123         166         800         123          73
# 3             256         160         205         833         167         104
# 4             197         140         295         605         145         104
# ...           ...         ...         ...         ...         ...         ...
# 23172        4796        1739        2041         676        3854        1398
# 23173        3916        1686        1879         639        2981        1283
# 23174        4422        2061        1969         702        2889        1347
# 23175        5025        2194        2174         682        3357        1466
# 23176        6022        2581        2561         676        3337        1430
#
#        b33_LC8_07  b34_LC8_07  b35_LC8_07
# 0              80         381         593
# 1              82         364         552
# 2              98         475         594
# 3             133         542         650
# 4             218         447         739
# ...           ...         ...         ...
# 23172        1640         543         804
# 23173        1430         486         761
# 23174        1286         459         653
# 23175        1452         456         668
# 23176        1419         375         554
#
# [23177 rows x 36 columns]

# %%
lakes_cdf_depth = cudf.DataFrame.from_pandas(lakes_df_depth)
lakes_cdf_data = cudf.DataFrame.from_pandas(lakes_df_data)
lakes_cdf_data.drop(['FID','Date'], axis = 1)
# Out:
#         Depth_m  b1_LC8_075  b2_LC8_075  b3_LC8_075  b4_LC8_075  b5_LC8_075  \
# 0      0.630000         164         271         199          42          27
# 1      0.672727         165         272         196          44          29
# 2      0.670588         154         260         193          40          32
# 3      0.822222         156         250         195          48          40
# 4      1.725000         117         164          78          38          23
# ...         ...         ...         ...         ...         ...         ...
# 23172  1.887000         103         284         242         731         494
# 23173  2.012610         155         360         323         950         607
# 23174  2.041730         199         427         447        1253         880
# 23175  1.986000         241         552         557        1776        1211
# 23176  1.766450         276         644         649        2459        1662
#
#        b6_LC8_075  b7_LC8_075  b8_LC8_075  b9_LC8_075  ...  b26_LC8_07  \
# 0              16         605         824        3905  ...        2625
# 1              16         607         842        3750  ...        2750
# 2              19         592         798        3850  ...        2105
# 3              26         624         800        3250  ...        1846
# 4              17         713        1500        3079  ...        2235
# ...           ...         ...         ...         ...  ...         ...
# 23172         397         363         426         141  ...        1841
# 23173         462         431         480         163  ...        2056
# 23174         575         466         445         159  ...        2179
# 23175         809         437         433         136  ...        2195
# 23176         921         429         425         112  ...        2670
#
#        b27_LC8_07  b28_LC8_07  b29_LC8_07  b30_LC8_07  b31_LC8_07  b32_LC8_07  \
# 0             165         100         136         643          98          59
# 1             176         107         148         659          97          59
# 2             208         123         166         800         123          73
# 3             256         160         205         833         167         104
# 4             197         140         295         605         145         104
# ...           ...         ...         ...         ...         ...         ...
# 23172        4796        1739        2041         676        3854        1398
# 23173        3916        1686        1879         639        2981        1283
# 23174        4422        2061        1969         702        2889        1347
# 23175        5025        2194        2174         682        3357        1466
# 23176        6022        2581        2561         676        3337        1430
#
#        b33_LC8_07  b34_LC8_07  b35_LC8_07
# 0              80         381         593
# 1              82         364         552
# 2              98         475         594
# 3             133         542         650
# 4             218         447         739
# ...           ...         ...         ...
# 23172        1640         543         804
# 23173        1430         486         761
# 23174        1286         459         653
# 23175        1452         456         668
# 23176        1419         375         554
#
# [23177 rows x 36 columns]

# %%
print("Main data")
lakes_cdf_data.dtypes
# Out:
# Main data
# FID             int64
# Depth_m       float64
# Date           object
# b1_LC8_075      int64
# b2_LC8_075      int64
# b3_LC8_075      int64
# b4_LC8_075      int64
# b5_LC8_075      int64
# b6_LC8_075      int64
# b7_LC8_075      int64
# b8_LC8_075      int64
# b9_LC8_075      int64
# b10_LC8_07      int64
# b11_LC8_07      int64
# b12_LC8_07      int64
# b13_LC8_07      int64
# b14_LC8_07      int64
# b15_LC8_07      int64
# b16_LC8_07      int64
# b17_LC8_07      int64
# b18_LC8_07      int64
# b19_LC8_07      int64
# b20_LC8_07      int64
# b21_LC8_07      int64
# b22_LC8_07      int64
# b23_LC8_07      int64
# b24_LC8_07      int64
# b25_LC8_07      int64
# b26_LC8_07      int64
# b27_LC8_07      int64
# b28_LC8_07      int64
# b29_LC8_07      int64
# b30_LC8_07      int64
# b31_LC8_07      int64
# b32_LC8_07      int64
# b33_LC8_07      int64
# b34_LC8_07      int64
# b35_LC8_07      int64
# dtype: object

# %%
print("")

# %%
print(lakes_cdf_depth.head(5))
print(lakes_cdf_data.head(5))
# Out:
#    FID   Latitude   Longitude  Depth_m
# 0    0  70.201515 -153.302756      2.6
# 1    1  70.201512 -153.302801      2.1
# 2    2  70.201509 -153.302837      2.2
# 3    3  70.201512 -153.302864      2.1
# 4    4  70.201506 -153.302918      2.0
#    FID   Depth_m            Date  b1_LC8_075  b2_LC8_075  b3_LC8_075  \
# 0    0  0.630000  7/22/2017 0:00         164         271         199
# 1    1  0.672727  7/22/2017 0:00         165         272         196
# 2    2  0.670588  7/22/2017 0:00         154         260         193
# 3    3  0.822222  7/22/2017 0:00         156         250         195
# 4    4  1.725000  7/22/2017 0:00         117         164          78
#
#    b4_LC8_075  b5_LC8_075  b6_LC8_075  b7_LC8_075  ...  b26_LC8_07  \
# 0          42          27          16         605  ...        2625
# 1          44          29          16         607  ...        2750
# 2          40          32          19         592  ...        2105
# 3          48          40          26         624  ...        1846
# 4          38          23          17         713  ...        2235
#
#    b27_LC8_07  b28_LC8_07  b29_LC8_07  b30_LC8_07  b31_LC8_07  b32_LC8_07  \
# 0         165         100         136         643          98          59
# 1         176         107         148         659          97          59
# 2         208         123         166         800         123          73
# 3         256         160         205         833         167         104
# 4         197         140         295         605         145         104
#
#    b33_LC8_07  b34_LC8_07  b35_LC8_07
# 0          80         381         593
# 1          82         364         552
# 2          98         475         594
# 3         133         542         650
# 4         218         447         739
#
# [5 rows x 38 columns]

# %%
X = lakes_cdf_data.drop(['FID', 'Depth_m', 'Date'], axis = 1)
X = X.astype(np.float64)

# %%
y = lakes_cdf_data['Depth_m']

# %%
from cuml import train_test_split
from cuml.linear_model import LinearRegression as cuLR
from cuml.metrics.regression import r2_score

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (18541, 35)
# (4636, 35)
# (18541,)
# (4636,)

# %%
from sklearn.metrics import mean_squared_error
lakes_lr = cuLR(fit_intercept=True, normalize=True, algorithm='eig')
lakes_lr.fit(X_train, y_train)
y_pred = lakes_lr.predict(X_test)
mse = mean_squared_error(y_test.to_array(), y_pred.to_array())
print(mse)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-eed2faf52c82> in <module>
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 lakes_lr = cuLR(fit_intercept=True, normalize=True, algorithm='eig')
#       3 lakes_lr.fit(X_train, y_train)
#       4 y_pred = lakes_lr.predict(X_test)
#       5 mse = mean_squared_error(y_test.to_array(), y_pred.to_array())
#
# cuml/linear_model/linear_regression.pyx in cuml.linear_model.linear_regression.LinearRegression.__init__()
#
# cuml/common/base.pyx in cuml.common.base.Base.__init__()
#
# cuml/common/handle.pyx in cuml.common.handle.Handle.__cinit__()
#
# RuntimeError: Exception occured! file=/conda/conda-bld/libcuml_1591208799167/work/cpp/src/common/cumlHandle.cpp line=202: FAIL: call='cudaStreamCreateWithFlags(&stream, cudaStreamNonBlocking)'. Reason:misaligned address
# Obtained 64 stack frames
# #0 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/pointer_utils.cpython-37m-x86_64-linux-gnu.so(_ZN8MLCommon9Exception16collectCallStackEv+0x3e) [0x7fd6d8e8813e]
# #1 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/pointer_utils.cpython-37m-x86_64-linux-gnu.so(_ZN8MLCommon9ExceptionC1ERKNSt7__cxx1112basic_stringIcSt11char_traitsIcESaIcEEE+0x80) [0x7fd6d8e88c50]
# #2 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/../../../../libcuml++.so(_ZN2ML15cumlHandle_impl15createResourcesEv+0x4a7) [0x7fd69626b3e7]
# #3 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/../../../../libcuml++.so(_ZN2ML15cumlHandle_implC1Ei+0x10a) [0x7fd69626b5fa]
# #4 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/../../../../libcuml++.so(_ZN2ML10cumlHandleC1Ei+0x22) [0x7fd69626b672]
# #5 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/handle.cpython-37m-x86_64-linux-gnu.so(+0x86ff) [0x7fd6d8bf76ff]
# #6 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x13a155) [0x556c1ea56155]
# #7 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/base.cpython-37m-x86_64-linux-gnu.so(+0xab24) [0x7fd6d8c19b24]
# #8 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/common/base.cpython-37m-x86_64-linux-gnu.so(+0x10385) [0x7fd6d8c1f385]
# #9 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyObject_FastCallDict+0x24f) [0x556c1ea3643f]
# #10 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x12e8d1) [0x556c1ea4a8d1]
# #11 in /home/cssprad1/.conda/envs/myRapids/lib/python3.7/site-packages/cuml/linear_model/linear_regression.cpython-37m-x86_64-linux-gnu.so(+0xa669) [0x7fd6d88f0669]
# #12 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyObject_FastCallDict+0x24f) [0x556c1ea3643f]
# #13 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x12e8d1) [0x556c1ea4a8d1]
# #14 in /home/cssprad1/.conda/envs/myRapids/bin/python(PyObject_Call+0x66) [0x556c1ea36ab6]
# #15 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0xc277a) [0x556c1e9de77a]
# #16 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyObject_FastCallKeywords+0x54c) [0x556c1ea9aeec]
# #17 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17f4e1) [0x556c1ea9b4e1]
# #18 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x13fe) [0x556c1eadfaee]
# #19 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalCodeWithName+0x252) [0x556c1ea34db2]
# #20 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x1d6e5e) [0x556c1eaf2e5e]
# #21 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyMethodDef_RawFastCallKeywords+0xe9) [0x556c1ea65079]
# #22 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x44c9) [0x556c1eae2bb9]
# #23 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17e344) [0x556c1ea9a344]
# #24 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x19e7) [0x556c1eae00d7]
# #25 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17e344) [0x556c1ea9a344]
# #26 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x19e7) [0x556c1eae00d7]
# #27 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17e344) [0x556c1ea9a344]
# #28 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyMethodDescr_FastCallKeywords+0xdb) [0x556c1ea9a6db]
# #29 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17f41e) [0x556c1ea9b41e]
# #30 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x611) [0x556c1eaded01]
# #31 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyFunction_FastCallKeywords+0x187) [0x556c1ea54767]
# #32 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x3f5) [0x556c1eadeae5]
# #33 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyFunction_FastCallKeywords+0x187) [0x556c1ea54767]
# #34 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17f335) [0x556c1ea9b335]
# #35 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x611) [0x556c1eaded01]
# #36 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalCodeWithName+0x252) [0x556c1ea34db2]
# #37 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyObject_FastCallDict+0x5be) [0x556c1ea367ae]
# #38 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x12e8d1) [0x556c1ea4a8d1]
# #39 in /home/cssprad1/.conda/envs/myRapids/bin/python(PyObject_Call+0x66) [0x556c1ea36ab6]
# #40 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x1cb3) [0x556c1eae03a3]
# #41 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalCodeWithName+0x85d) [0x556c1ea353bd]
# #42 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyFunction_FastCallKeywords+0x583) [0x556c1ea54b63]
# #43 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17f335) [0x556c1ea9b335]
# #44 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x13fe) [0x556c1eadfaee]
# #45 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x193645) [0x556c1eaaf645]
# #46 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyMethodDef_RawFastCallKeywords+0xe9) [0x556c1ea65079]
# #47 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x44c9) [0x556c1eae2bb9]
# #48 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalCodeWithName+0x85d) [0x556c1ea353bd]
# #49 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyFunction_FastCallKeywords+0x583) [0x556c1ea54b63]
# #50 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x17f335) [0x556c1ea9b335]
# #51 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x611) [0x556c1eaded01]
# #52 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x193645) [0x556c1eaaf645]
# #53 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyMethodDef_RawFastCallKeywords+0xe9) [0x556c1ea65079]
# #54 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x44c9) [0x556c1eae2bb9]
# #55 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalCodeWithName+0x85d) [0x556c1ea353bd]
# #56 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyFunction_FastCallKeywords+0x583) [0x556c1ea54b63]
# #57 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x3f5) [0x556c1eadeae5]
# #58 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x193645) [0x556c1eaaf645]
# #59 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyMethodDef_RawFastCallKeywords+0xe9) [0x556c1ea65079]
# #60 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalFrameDefault+0x44c9) [0x556c1eae2bb9]
# #61 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyEval_EvalCodeWithName+0x85d) [0x556c1ea353bd]
# #62 in /home/cssprad1/.conda/envs/myRapids/bin/python(_PyObject_FastCallDict+0x312) [0x556c1ea36502]
# #63 in /home/cssprad1/.conda/envs/myRapids/bin/python(+0x12e8d1) [0x556c1ea4a8d1]
